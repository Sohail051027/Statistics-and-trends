# %%
import pandas as pd
from google.colab import files

uploaded = files.upload()
# Out:
#      <input type="file" id="files-3e34622b-afd7-47ed-b7ce-d90543fba04d" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-3e34622b-afd7-47ed-b7ce-d90543fba04d">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
import pandas as pd
# Replace 'your_dataset.csv' with the actual name of your dataset
df = pd.read_csv('climatedata 1 (1).csv')
df.head()
df.describe()
# Out:
#               year   Afghanistan  Afghanistan.1  Afghanistan.2       Bahrain  \
# count    63.000000  6.300000e+01      22.000000      61.000000  6.300000e+01
# mean   1991.000000  3.896487e+06      55.817603  379600.131148  5.855856e+05
# std      18.330303  2.948780e+06      33.034726    1160.774030  3.946879e+05
# min    1960.000000  7.243730e+05       4.446891  377500.000000  1.322810e+05
# 25%    1975.500000  1.694114e+06      29.888359  379100.000000  2.489660e+05
# 50%    1991.000000  2.285067e+06      45.750513  379550.000000  4.729270e+05
# 75%    2006.500000  5.907622e+06      92.448158  380490.000000  8.897990e+05
# max    2022.000000  1.094683e+07      97.700000  383130.000000  1.335714e+06
#
#         Bahrain.1   Bahrain.2  Canada(Urban population)  \
# count   32.000000   61.000000              6.300000e+01
# mean    99.996653   95.818033              2.188325e+07
# std      0.011793    6.700585              5.431796e+06
# ...

# %%
correlation_matrix = df.corr()

import seaborn as sns
import matplotlib.pyplot as plt

plt.figure(figsize=(20, 18))
sns.heatmap(correlation_matrix, annot=True, cmap='coolwarm', fmt=".2f")
plt.show()

import pandas as pd
import matplotlib.pyplot as plt

# Replace 'your_dataset.csv' with the actual filename or URL
df = pd.read_csv('climatedata 1 (1).csv')

# Set the index of the DataFrame to the first column if it contains the years or time-related data
df.set_index(df.columns[0], inplace=True)

# Plotting trend graphs for selected columns
columns_of_interest = ['Afghanistan', 'Bahrain', 'Canada(Urban population)', 'Canada(Access to electricity (% of population))']

plt.figure(figsize=(12, 8))

for column in columns_of_interest:
    plt.plot(df.index, df[column], label=column)

plt.title('Trend Graphs for Selected Countries')
plt.xlabel('Year or Time')
plt.ylabel('Values')
plt.legend()
plt.show()


# Bar graph
plt.figure(figsize=(10, 6))
df_bar = df[columns_of_interest].mean()  # Using mean values for the bar graph
df_bar.plot(kind='bar', color='skyblue')
plt.title('Average Values for Selected Countries')
plt.xlabel('Country/Indicator')
plt.ylabel('Average Values')
plt.show()

# Pie chart
plt.figure(figsize=(8, 8))
plt.pie(df_bar, labels=df_bar.index, autopct='%1.1f%%', startangle=90, colors=['lightcoral', 'lightblue', 'lightgreen', 'lightpink'])
plt.title('Percentage Distribution of Average Values for Selected Countries/Indicators')
plt.show()
